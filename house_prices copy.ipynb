# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from IPython.display import Image

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
train = pd.read_csv('./house_prices_train.csv')
test = pd.read_csv('./house_prices_test.csv')

# %%
fig, ax = plt.subplots()
ax.scatter(x = train['GrLivArea'], y = train['SalePrice'])
plt.ylabel('SalePrice', fontsize=13)
plt.xlabel('GrLivArea', fontsize=13)
plt.show()

# %%
train = train.drop(train[(train['GrLivArea']>4000) & (train['SalePrice']<300000)].index)

# %%
fig, ax = plt.subplots()
ax.scatter(train['GrLivArea'], train['SalePrice'])
plt.ylabel('SalePrice', fontsize=13)
plt.xlabel('GrLivArea', fontsize=13)
plt.show()

# %%
cor = train.corr(numeric_only=True)
cor_fe = cor.index[abs(cor['SalePrice']) >= 0.2]
cor_fe
# Out:
# Index(['LotFrontage', 'LotArea', 'OverallQual', 'YearBuilt', 'YearRemodAdd',
#        'MasVnrArea', 'BsmtFinSF1', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF',
#        '2ndFlrSF', 'GrLivArea', 'BsmtFullBath', 'FullBath', 'HalfBath',
#        'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea',
#        'WoodDeckSF', 'OpenPorchSF', 'SalePrice'],
#       dtype='object')

# %%
plt.figure(figsize=(15,10))
sns.heatmap(train[cor_fe].corr(),annot=True)
# Out:
# <Axes: >

# %%
row = 12
col = 4 

fig, axs = plt.subplots(row,col, figsize = (col*4,row*3))

for r in range(0,row):
    for c in range(0,col):
        i = r*col + c
        # if i < len(li_obj):
        #     sns.boxplot(train[li_obj[i]],target , ax = axs[r][c])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 row = 12
#       2 col = 4
# ----> 4 fig, axs = plt.subplots(row,col, figsize = (col*4,row*3))
#       6 for r in range(0,row):
#       7     for c in range(0,col):
#
# NameError: name 'plt' is not defined
